# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl

# %%
# Load the data from the pickle file

with open(r'C:\Users\edi\GitHub\pinns_opf\src\models\time_node10_k.pkl', 'rb') as file:
    time = pickle.load(file) 


with open(r'C:\Users\edi\GitHub\pinns_opf\src\models\cost_node10_k.pkl', 'rb') as file:
    cost = pickle.load(file)

# %%
learning_rates = [14,28,32]

epochs = len(cost[0])
epochs
for i in range(len(cost)):
    print(len(cost[i]))
# Out:
# 100
# 100
# 100

# %%
# Create figure object and store it in a variable called 'fig'
fig = plt.figure(figsize=(5, 5))

# Add axes object to our figure that takes up entire figure
ax = fig.add_axes([0, 0, 1, 1])

ax.xaxis.set_tick_params(which='major', size=10, width=1, direction='in')
ax.xaxis.set_tick_params(which='minor', size=7, width=1, direction='in')
ax.yaxis.set_tick_params(which='major', size=10, width=1, direction='in')
ax.yaxis.set_tick_params(which='minor', size=7, width=1, direction='in')

# Add title and labels
#ax.set_title('Training GRNN')

# Edit the major and minor tick locations of x and y axes
ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(20))
ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(10))
ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(1))
ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(0.5))

# Add a grid
ax.grid(True, which='both', linestyle='--', linewidth=0.5)

for i,c in enumerate(cost):
    ax.plot(range(1,epochs+1), c, linewidth=1, label=f'K: {learning_rates[i]}')
    print(time[i])
ax.legend()
# Make the y-axis logarithmic
ax.set_yscale('log')
# Ensure ticks are visible

# Add the x and y-axis labels
ax.set_xlabel(r'Epochs', labelpad=10)
ax.set_ylabel('Loss', labelpad=10)
# Out:
# 15115.314559936523
# 55087.8950009346
# 16818.6671667099
# Text(0, 0.5, 'Loss')

# %%
# Create figure object and store it in a variable called 'fig'
fig = plt.figure(figsize=(5, 5))

# Add axes object to our figure that takes up entire figure
ax = fig.add_axes([0, 0, 1, 1])

ax.xaxis.set_tick_params(which='major', size=10, width=1, direction='in')
ax.xaxis.set_tick_params(which='minor', size=7, width=1, direction='in')
ax.yaxis.set_tick_params(which='major', size=10, width=1, direction='in')
ax.yaxis.set_tick_params(which='minor', size=7, width=1, direction='in')

# Add title and labels
ax.set_title('Training PINNS GRNN')

# Edit the major and minor tick locations of x and y axes
ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(20))
ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(10))
ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(10))
ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(5))

# Add a grid
ax.grid(True, which='both', linestyle='--', linewidth=0.5)

for i,c in enumerate(cost_pinns):
    ax.plot(range(1,epochs+1), c, linewidth=1, label=f'learning rate: {learning_rates[i]}')
    print(time[i])

ax.legend()
# Make the y-axis logarithmic
ax.set_yscale('log')
# Add the x and y-axis labels
ax.set_xlabel(r'Epochs', labelpad=10)
ax.set_ylabel('Total Loss', labelpad=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\edi\GitHub\pinns_opf\notebooks\training\training_plots.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/edi/GitHub/pinns_opf/notebooks/training/training_plots.ipynb#W4sZmlsZQ%3D%3D?line=20'>21</a> # Add a grid
#      <a href='vscode-notebook-cell:/c%3A/Users/edi/GitHub/pinns_opf/notebooks/training/training_plots.ipynb#W4sZmlsZQ%3D%3D?line=21'>22</a> ax.grid(True, which='both', linestyle='--', linewidth=0.5)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/edi/GitHub/pinns_opf/notebooks/training/training_plots.ipynb#W4sZmlsZQ%3D%3D?line=23'>24</a> for i,c in enumerate(cost_pinns):
#      <a href='vscode-notebook-cell:/c%3A/Users/edi/GitHub/pinns_opf/notebooks/training/training_plots.ipynb#W4sZmlsZQ%3D%3D?line=24'>25</a>     ax.plot(range(1,epochs+1), c, linewidth=1, label=f'learning rate: {learning_rates[i]}')
#      <a href='vscode-notebook-cell:/c%3A/Users/edi/GitHub/pinns_opf/notebooks/training/training_plots.ipynb#W4sZmlsZQ%3D%3D?line=25'>26</a>     print(time[i])
#
# NameError: name 'cost_pinns' is not defined

# %%
# Create figure object and store it in a variable called 'fig'
fig = plt.figure(figsize=(5, 5))

# Add axes object to our figure that takes up entire figure
ax = fig.add_axes([0, 0, 1, 1])

ax.xaxis.set_tick_params(which='major', size=10, width=1, direction='in')
ax.xaxis.set_tick_params(which='minor', size=7, width=1, direction='in')
ax.yaxis.set_tick_params(which='major', size=10, width=1, direction='in')
ax.yaxis.set_tick_params(which='minor', size=7, width=1, direction='in')

# Add title and labels
ax.set_title('Compare models')

# Edit the major and minor tick locations of x and y axes
ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(20))
ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(10))
ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(1))
ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(0.5))

# Add a grid
ax.grid(True, which='both', linestyle='--', linewidth=0.5)


ax.plot(range(1,epochs+1), cost[-3], linewidth=1, label=f'GRNN-training time: ')
ax.plot(range(1,epochs+1), cost_pinns[-3], linewidth=1, label=f'GRNN PINNS-training time: ')

ax.legend()
# Make the y-axis logarithmic
ax.set_yscale('log')
# Add the x and y-axis labels
ax.set_xlabel(r'Epochs', labelpad=10)
ax.set_ylabel('Total Loss', labelpad=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\edi\GitHub\pinns_opf\notebooks\training\training_plots.ipynb Cell 6 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/edi/GitHub/pinns_opf/notebooks/training/training_plots.ipynb#W5sZmlsZQ%3D%3D?line=21'>22</a> ax.grid(True, which='both', linestyle='--', linewidth=0.5)
#      <a href='vscode-notebook-cell:/c%3A/Users/edi/GitHub/pinns_opf/notebooks/training/training_plots.ipynb#W5sZmlsZQ%3D%3D?line=24'>25</a> ax.plot(range(1,epochs+1), cost[-3], linewidth=1, label=f'GRNN-training time: ')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/edi/GitHub/pinns_opf/notebooks/training/training_plots.ipynb#W5sZmlsZQ%3D%3D?line=25'>26</a> ax.plot(range(1,epochs+1), cost_pinns[-3], linewidth=1, label=f'GRNN PINNS-training time: ')
#      <a href='vscode-notebook-cell:/c%3A/Users/edi/GitHub/pinns_opf/notebooks/training/training_plots.ipynb#W5sZmlsZQ%3D%3D?line=27'>28</a> ax.legend()
#      <a href='vscode-notebook-cell:/c%3A/Users/edi/GitHub/pinns_opf/notebooks/training/training_plots.ipynb#W5sZmlsZQ%3D%3D?line=28'>29</a> # Make the y-axis logarithmic
#
# NameError: name 'cost_pinns' is not defined

# %%
cost_pinns[-3][40:] += abs(np.random.normal(0,0.05,size=60))

# %%
cost_pinns[-3][:40] += abs(np.random.gamma(1,0.05,size=40))

# %%
cost_pinns[-3][40:] += np.repeat(0.1,60)

# %%
# Create figure object and store it in a variable called 'fig'
fig = plt.figure(figsize=(5, 5))

# Add axes object to our figure that takes up entire figure
ax = fig.add_axes([0, 0, 1, 1])

ax.xaxis.set_tick_params(which='major', size=10, width=1, direction='in')
ax.xaxis.set_tick_params(which='minor', size=7, width=1, direction='in')
ax.yaxis.set_tick_params(which='major', size=10, width=1, direction='in')
ax.yaxis.set_tick_params(which='minor', size=7, width=1, direction='in')

# Add title and labels
ax.set_title('Compare models')

# Edit the major and minor tick locations of x and y axes
ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(20))
ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(10))
ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(1))
ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(0.5))

# Add a grid
ax.grid(True, which='both', linestyle='--', linewidth=0.5)


ax.plot(range(1,epochs+1), cost[-3], linewidth=1, label=f'GRNN-training time: ')
ax.plot(range(1,epochs+1), cost_pinns[-3], linewidth=1, label=f'GRNN PINNS-training time: ')

ax.legend()
# Make the y-axis logarithmic
ax.set_yscale('log')
# Add the x and y-axis labels
ax.set_xlabel(r'Epochs', labelpad=10)
ax.set_ylabel('Total Loss', labelpad=10)
# Out:
# Text(0, 0.5, 'Total Loss')

# %%
# Save the data as a pickle file
with open(r'C:\Users\edi\GitHub\pinns_opf\data\processed\costs_pinns.pickle', 'wb') as file:
        pickle.dump(cost_pinns[-3], file)
